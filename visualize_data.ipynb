# %%
import matplotlib.pyplot as plt
import numpy as np
from chainercv import transforms
import pathlib
import cv2
# Out:
# /home/yohei/.pyenv/versions/3.6.4/envs/chainer/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # visualize data

# %%
data_path = pathlib.Path("../data/CelebA/Img/img_align_celeba/").resolve()
save_path = pathlib.Path("../data/CelebA/Img/center_cropped_resize_64").resolve()
if not save_path.exists():
    save_path.mkdir()

# %%
height, width = 218, 178
dx,dy = 128, 128
is_resize=True
#cnt=0
for path in data_path.glob("*.jpg"):
    #f cnt<10:
    img = cv2.imread(str(path))
    #plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    #plt.show()
    cropped_img = img[height//2 - dx // 2:height//2 + dx // 2,
                          width//2 - dy // 2:width//2 + dy // 2]
    if is_resize:
        cropped_img= cv2.resize(cropped_img, dsize=(64, 64),
                                interpolation=cv2.INTER_LANCZOS4)
    #plt.imshow(cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB))
    #plt.show()

    # save
    cv2.imwrite(
        str(save_path / path.name), cropped_img)

# %%
save_path = pathlib.Path("../data/CelebA/Img/center_cropped_128").resolve()
if not save_path.exists():
    save_path.mkdir()

height, width = 218, 178
dx,dy = 128, 128
is_resize=False
#cnt=0
for path in data_path.glob("*.jpg"):
    #f cnt<10:
    img = cv2.imread(str(path))
    #plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    #plt.show()
    cropped_img = img[height//2 - dx // 2:height//2 + dx // 2,
                          width//2 - dy // 2:width//2 + dy // 2]
    if is_resize:
        cropped_img= cv2.resize(cropped_img, dsize=(64, 64),
                                interpolation=cv2.INTER_LANCZOS4)
    #plt.imshow(cv2.cvtColor(cropped_img, cv2.COLOR_BGR2RGB))
    #plt.show()

    # save
    cv2.imwrite(
        str(save_path / path.name), cropped_img)

# %%
cnt=0
for path in save_path.glob("*jpg"):
    img = cv2.imread(str(path))
    fig, ax = plt.subplots(1,1, figsize=(2,2))
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    fig.show()
    cnt+=1
    if cnt>10:
        break
# Out:
# /home/yohei/.pyenv/versions/3.6.4/envs/chainer/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
cropped_path = pathlib.Path("../data/CelebA/Img/center_cropped_resize_64/").resolve()
img_path = [path for path in cropped_path.glob("*jpg")]

# %%
fig, axes = plt.subplots(5, 5, figsize=(12,12))
i=9998
for offset ,ax in enumerate(axes.flatten()):
    path = img_path[i+offset]
    img = cv2.imread(str(path))
    ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    ax.axis("off")
    i+=1
fig.subplots_adjust(wspace=-0.01, hspace=-0.01)
fig.savefig("data_visualization.png", bbox_inches="tight", pad_inches=0.0)

# %%
next(cropped_path.glob("*jpg"))
